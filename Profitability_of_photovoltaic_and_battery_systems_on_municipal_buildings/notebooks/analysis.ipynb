# %%
# %load_ext autoreload
# %autoreload

# %%
import sys 

sys.path.append("..")

from project.utils  import *
from project.config import *
from project.main   import *
# Out:
# SCR with obj.function: min electricity procurement cost=85.5284776556678%
# SSR with obj.function: min electricity procurement cost=38.14388593570903%
# SCR with obj.function: min electricity procurement cost and peak power feed-in=85.5284776556678%
# SSR with obj.function: min electricity procurement cost and peak power feed-in=38.14388593570903%

# %%
plt.figure(1, figsize=(12, 10)) 
plt.subplot(3,1,1)
plt.plot(hour_in_year, df_result['E_PV'],'r',label = 'Energy PV')
plt.plot(hour_in_year, df_result['E_demand'],'b',label = 'Energy Demand')
plt.ylabel('Energy (kWh)')
plt.title('Energy Demand and Energy Production of PV (First Objective Function)')
plt.xlabel('Cumulative hour')
plt.legend()


plt.subplot(3,1,2)
plt.plot(hour_in_year, df_result["E_supply"],'y',label = 'Energy Supply')
plt.plot(hour_in_year, df_result["E_feedin"],'g',label = 'Energy Feed-in')
plt.ylabel('Energy (kWh)')
plt.title('Energy Supplied and Fed to the Grid (First Objective Function)')
plt.xlabel('Cumulative hour')
plt.legend()


plt.subplot(3,1,3)
plt.plot(hour_in_year, df_result["SOC"])
plt.ylabel('Energy (kWh)')
plt.title('SOC of the Battery (First Objective Function)')
plt.xlabel('Cumulative hour')



plt.subplots_adjust(left=0.1, 
    bottom=0.1,  
    right=1.1,  
    top=1.2,  
    wspace=0.5,  
    hspace=0.5) 

plt.show()
